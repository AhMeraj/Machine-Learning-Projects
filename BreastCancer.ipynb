# %%
#Breast Cancer prediction by using StandardScaler and LogisticRegression

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-ba84c79d-adab-471d-a6ca-12880f0eaa80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba84c79d-adab-471d-a6ca-12880f0eaa80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving breast-cancer.xlsx to breast-cancer.xlsx
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_excel('breast-cancer.xlsx')

# %%
df
# Out:
#            id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302          1  ...          0.4601                  0.11890
# 1      842517          1  ...          0.2750                  0.08902
# 2    84300903          1  ...          0.3613                  0.08758
# 3    84348301          1  ...          0.6638                  0.17300
# 4    84358402          1  ...          0.2364                  0.07678
# ..        ...        ...  ...             ...                      ...
# 564    926424          1  ...          0.2060                  0.07115
# 565    926682          1  ...          0.2572                  0.06637
# 566    926954          1  ...          0.2218                  0.07820
# 567    927241          1  ...          0.4087                  0.12400
# 568     92751          0  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df=df.drop(['id'],axis=1)

# %%
x=df.drop(['diagnosis'],axis=1)

# %%
y=df['diagnosis']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
Logi=LogisticRegression()

# %%
Logi.fit(xtrain,ytrain)
Logi.score(xtest,ytest)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.9473684210526315

# %%
Scaler=StandardScaler()

# %%
Sx=Scaler.fit_transform(x)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(Sx,y,test_size=0.2,random_state=1)

# %%
Logi.fit(xtrain,ytrain)
Logi.score(xtest,ytest)
# Out:
# 0.9736842105263158

# %%
pred=Logi.predict(xtest)

# %%
confusion_matrix(ytest,pred)
# Out:
# array([[71,  1],
#        [ 2, 40]])

# %%
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        72
#            1       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
